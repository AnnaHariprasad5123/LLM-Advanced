# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional
plt.plot(x,y)
# plt.show()

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
## Object Oriented

fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # left, bottom, width and height
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) 

axes1.plot(x,y)
axes1.set_title("Larger plot")

axes2.plot(y,x)
axes2.set_title("Smaller plot")
# Out:
# Text(0.5, 1.0, 'Smaller plot')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)
plt.tight_layout() # help to fix the overlapped plots

for current_ax in axes:  # axes can be iterate over the loops
    current_ax.plot(x,y)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('LEFT PLOT')

axes[1].plot(y,x)
axes[1].set_title('RIGHT PLOT')
# Out:
# Text(0.5, 1.0, 'RIGHT PLOT')

# %% [markdown]
# #### Figure Size and DPI

# %%
fig = plt.figure(figsize=(8,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title("Title")
ax.set_xlabel("X Label")
ax.set_ylabel("Y Label")
# Out:
# Text(0, 0.5, 'Y Label')

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)
fig.tight_layout()

# %%
fig.savefig('my_picture.png', dpi=200) # Help to save the plot in the system

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label="X Squared")
ax.plot(x,x**3, label="X Cubed")
#ax.legend(loc="upper center") # upper left, upper center, upper right, ...
ax.legend(loc=(0.1,0.1))

# %% [markdown]
# #### Plot Apperance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
#ax.plot(x,y**2,color="purple", linewidth=3, alpha=0.5, linestyle='dotted',marker="o",markersize=10)
ax.plot(x,y**2,color="red", lw=3, alpha=0.5, ls='dotted', marker="o",markersize=20, markerfacecolor="yellow",markeredgewidth=3, markeredgecolor='green')
#ax.set_xlim([0,1])
#ax.set_ylim([0,2]) # upper bound and lower bound

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")

# %% [markdown]
# #### Plot range

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# #### Special Plot Types

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([11.,  5.,  7.,  9., 12.,  9.,  9.,  9., 16., 13.]),
#  array([ 14. , 111.5, 209. , 306.5, 404. , 501.5, 599. , 696.5, 794. ,
#         891.5, 989. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);
